# %%
import breeze_client as bc
import plotly.graph_objects as go
import pandas as pd

# %%
filename = 'data/NIFTY/NIFTY_2024-05-30_22800_call_1second_2024-05-23.csv'
data = bc.read_csv(filename)
data
# Out:
#                       Close exchange_code  expiry_date    High     Low  \
# datetime
# 2024-05-23 09:15:00   94.85           NFO  30-MAY-2024   94.85   94.85
# 2024-05-23 09:15:00   94.85           NFO  30-MAY-2024   94.85   94.85
# 2024-05-23 09:15:01  103.30           NFO  30-MAY-2024  103.30  103.30
# 2024-05-23 09:15:04  100.00           NFO  30-MAY-2024  100.00  100.00
# 2024-05-23 09:15:05  101.20           NFO  30-MAY-2024  101.20  101.20
# ...                     ...           ...          ...     ...     ...
# 2024-05-23 15:29:54  294.10           NFO  30-MAY-2024  296.40  294.10
# 2024-05-23 15:29:55  295.00           NFO  30-MAY-2024  295.00  294.10
# 2024-05-23 15:29:57  295.00           NFO  30-MAY-2024  295.00  295.00
# 2024-05-23 15:29:58  295.00           NFO  30-MAY-2024  295.00  295.00
# 2024-05-23 15:29:59  295.00           NFO  30-MAY-2024  295.00  295.00
#
#                        Open  open_interest product_type right stock_code  \
# datetime
# ...

# %%
df = data

# Create candlestick chart
fig = go.Figure(data=[go.Candlestick(x=df.index,
                                     open=df['Open'],
                                     high=df['High'],
                                     low=df['Low'],
                                     close=df['Close'])])

# Add titles and labels
fig.update_layout(title='Stock Price Data',
                  xaxis_title='Date',
                  yaxis_title='Price',
                  xaxis_rangeslider_visible=True)

# Save as HTML file
fig.write_html("candlestick_chart.html")

# Show plot in the browser (optional)
fig.show()

# %%
fig.write_html('nifty_options_candlestick_chart.html')
