# %% [markdown]
# This File is to collect Historical data from breeze api and then store it to /data/data.csv to re use the data later no need to gegnrate again

# %%
import pandas as pd
import backtesting as bt
import pandas_ta as ta
import numpy as np
import datetime as dt
from breeze_connect import BreezeConnect
import datetime as dt
from breeze_client import icici_client
from IPython.display import clear_output
import os

# %%
key = '73=63fT44781tY4C42L0i3491201v23A'
session_code = '40227774'
secret_key = '11331XF5fm6c5&Y3K2Q99lp28347480+'

# %%
bz = icici_client(apikey=key,secret_key=secret_key,session_code=session_code)

# %% [markdown]
# ### To get the data for Stock data
# Note : NOT for Options or future. If you want to get options or futures data see the bottom of this file

# %%
symbol = 'NESIND'
interval = '1minute'
period = 30
period_unit = 'd'

# %%
data = bz.download(symbol,interval,period=str(period)+period_unit)
data
# Out:
#        Close             datetime exchange_code     High      Low     Open  \
# 0    2519.45  2024-04-29 11:22:00           NSE  2519.50  2518.35  2518.40
# 1    2518.50  2024-04-29 11:23:00           NSE  2519.45  2517.35  2519.40
# 2    2517.20  2024-04-29 11:24:00           NSE  2518.45  2517.00  2518.45
# 3    2514.25  2024-04-29 11:25:00           NSE  2518.10  2514.25  2518.10
# 4    2515.00  2024-04-29 11:26:00           NSE  2515.30  2514.00  2515.00
# ..       ...                  ...           ...      ...      ...      ...
# 995  2509.25  2024-05-02 15:25:00           NSE  2511.45  2508.70  2509.00
# 996  2510.20  2024-05-02 15:26:00           NSE  2511.80  2507.75  2510.30
# 997  2508.80  2024-05-02 15:27:00           NSE  2512.00  2507.05  2509.55
# 998  2508.90  2024-05-02 15:28:00           NSE  2510.50  2505.00  2507.45
# 999  2511.00  2024-05-02 15:29:00           NSE  2515.00  2508.00  2508.50
#
#     stock_code  Volume
# 0       NESIND    1172
# 1       NESIND    1072
# 2       NESIND     461
# 3       NESIND    1439
# 4       NESIND     710
# ..         ...     ...
# 995     NESIND    9039
# 996     NESIND   10066
# 997     NESIND   10043
# 998     NESIND    3883
# 999     NESIND    1670
#
# [1000 rows x 8 columns]

# %%
dfs = []
for days in range(0,period+1):
    latest_date = dt.date.today()-dt.timedelta(days=days)
    result = bz.download(symbol,interval,'1d',latest_date=latest_date)
    dfs.append(result)
    clear_output()
    print(f'{round(days/period*100,2)} Completed')
# Out:
# 100.0 Completed

# %%
df = pd.concat(dfs,ignore_index=True)
df
# Out:
#         Close             datetime exchange_code     High      Low     Open  \
# 0     2507.40  2024-05-02 09:07:00           NSE  2510.00  2507.40  2510.00
# 1     2512.55  2024-05-02 09:15:00           NSE  2519.00  2507.50  2507.50
# 2     2514.70  2024-05-02 09:16:00           NSE  2515.45  2507.05  2512.50
# 3     2514.50  2024-05-02 09:17:00           NSE  2519.00  2513.25  2514.70
# 4     2517.95  2024-05-02 09:18:00           NSE  2518.80  2514.70  2515.60
# ...       ...                  ...           ...      ...      ...      ...
# 7139  2556.50  2024-04-03 15:25:00           NSE  2558.15  2555.00  2555.35
# 7140  2556.00  2024-04-03 15:26:00           NSE  2557.85  2555.00  2557.75
# 7141  2555.70  2024-04-03 15:27:00           NSE  2557.85  2554.50  2556.00
# 7142  2555.50  2024-04-03 15:28:00           NSE  2556.00  2555.25  2555.65
# 7143  2554.40  2024-04-03 15:29:00           NSE  2555.95  2554.40  2555.25
#
#      stock_code  Volume
# 0        NESIND      37
# 1        NESIND   13646
# 2        NESIND    7678
# 3        NESIND    4407
# 4        NESIND    4112
# ...         ...     ...
# 7139     NESIND   10610
# 7140     NESIND    9914
# 7141     NESIND   13483
# 7142     NESIND    5410
# 7143     NESIND   13575
#
# [7144 rows x 8 columns]

# %%
df.sort_values('datetime').reset_index(drop=True,inplace=True)

# %%
filename = f'data/{symbol}/{symbol}_{interval}_{period}{period_unit}.csv'

try:

    df.to_csv(filename,index=False)

except OSError as e:
    print(e)
    os.mkdir(f'data/{symbol}')
    df.to_csv(filename,index=False)

# %%
pd.read_csv(filename)
# Out:
#         Close             datetime exchange_code     High      Low     Open  \
# 0     2507.40  2024-05-02 09:07:00           NSE  2510.00  2507.40  2510.00
# 1     2512.55  2024-05-02 09:15:00           NSE  2519.00  2507.50  2507.50
# 2     2514.70  2024-05-02 09:16:00           NSE  2515.45  2507.05  2512.50
# 3     2514.50  2024-05-02 09:17:00           NSE  2519.00  2513.25  2514.70
# 4     2517.95  2024-05-02 09:18:00           NSE  2518.80  2514.70  2515.60
# ...       ...                  ...           ...      ...      ...      ...
# 7139  2556.50  2024-04-03 15:25:00           NSE  2558.15  2555.00  2555.35
# 7140  2556.00  2024-04-03 15:26:00           NSE  2557.85  2555.00  2557.75
# 7141  2555.70  2024-04-03 15:27:00           NSE  2557.85  2554.50  2556.00
# 7142  2555.50  2024-04-03 15:28:00           NSE  2556.00  2555.25  2555.65
# 7143  2554.40  2024-04-03 15:29:00           NSE  2555.95  2554.40  2555.25
#
#      stock_code  Volume
# 0        NESIND      37
# 1        NESIND   13646
# 2        NESIND    7678
# 3        NESIND    4407
# 4        NESIND    4112
# ...         ...     ...
# 7139     NESIND   10610
# 7140     NESIND    9914
# 7141     NESIND   13483
# 7142     NESIND    5410
# 7143     NESIND   13575
#
# [7144 rows x 8 columns]

# %% [markdown]
# ### To get the data for Options or Future

# %%
symbol = 'NESIND'
interval = '1minute'
period = 30
period_unit = 'd'
strike_price=2600
right='call'
expiry_date='30-5-2024'
product_type = 'futures'

# %%
data = bz.download(symbol,interval,period=str(period)+period_unit,exchange_code='NFO',product_type=product_type,expiry_date=expiry_date,right=right,strike_price=strike_price)
data
# Out:
# 2024-05-30
#        Close             datetime exchange_code  expiry_date     High  \
# 0    2538.25  2024-04-29 11:20:00           NFO  30-MAY-2024  2538.35
# 1    2537.30  2024-04-29 11:21:00           NFO  30-MAY-2024  2538.85
# 2    2538.20  2024-04-29 11:22:00           NFO  30-MAY-2024  2538.20
# 3    2538.10  2024-04-29 11:23:00           NFO  30-MAY-2024  2538.60
# 4    2536.70  2024-04-29 11:24:00           NFO  30-MAY-2024  2538.10
# ..       ...                  ...           ...          ...      ...
# 995  2533.75  2024-05-02 15:25:00           NFO  30-MAY-2024  2535.30
# 996  2534.25  2024-05-02 15:26:00           NFO  30-MAY-2024  2535.95
# 997  2532.85  2024-05-02 15:27:00           NFO  30-MAY-2024  2535.75
# 998  2533.00  2024-05-02 15:28:00           NFO  30-MAY-2024  2535.30
# 999  2531.65  2024-05-02 15:29:00           NFO  30-MAY-2024  2537.35
#
#          Low     Open  open_interest product_type stock_code  Volume
# 0    2537.50  2537.55        5719600      Futures     NESIND    1200
# 1    2537.30  2538.25        5720000      Futures     NESIND    1000
# 2    2537.30  2537.30        5720000      Futures     NESIND     400
# 3    2538.10  2538.60        5720000      Futures     NESIND    1000
# 4    2536.70  2538.10        5720000      Futures     NESIND     200
# ..       ...      ...            ...          ...        ...     ...
# 995  2533.00  2533.85        5707000      Futures     NESIND    8600
# 996  2532.80  2533.75        5707000      Futures     NESIND   10000
# 997  2531.25  2534.25        5707000      Futures     NESIND    6400
# 998  2531.65  2532.85        5724400      Futures     NESIND    7400
# 999  2531.65  2533.00        5724400      Futures     NESIND    4600
#
# [1000 rows x 11 columns]

# %%
dfs = []
for days in range(0,period+1):
    latest_date = dt.date.today()-dt.timedelta(days=days)
    result = bz.download(symbol,interval,'1d',latest_date=latest_date,exchange_code='NFO',product_type=product_type,expiry_date=expiry_date,right=right,strike_price=strike_price)
    dfs.append(result)
    clear_output()
    print(f'{round(days/period*100,2)} Completed')
# Out:
# 100.0 Completed

# %%
df = pd.concat(dfs,ignore_index=True)
df
# Out:
#         Close             datetime exchange_code  expiry_date     High  \
# 0     2526.15  2024-05-02 09:15:00           NFO  30-MAY-2024  2550.85
# 1     2527.00  2024-05-02 09:16:00           NFO  30-MAY-2024  2530.15
# 2     2532.20  2024-05-02 09:17:00           NFO  30-MAY-2024  2536.20
# 3     2533.00  2024-05-02 09:18:00           NFO  30-MAY-2024  2533.00
# 4     2536.45  2024-05-02 09:19:00           NFO  30-MAY-2024  2537.10
# ...       ...                  ...           ...          ...      ...
# 7096  2577.10  2024-04-03 15:25:00           NFO  30-MAY-2024  2577.10
# 7097  2577.50  2024-04-03 15:26:00           NFO  30-MAY-2024  2577.50
# 7098  2577.50  2024-04-03 15:27:00           NFO  30-MAY-2024  2577.50
# 7099  2577.50  2024-04-03 15:28:00           NFO  30-MAY-2024  2577.50
# 7100  2576.00  2024-04-03 15:29:00           NFO  30-MAY-2024  2576.00
#
#           Low     Open  open_interest product_type stock_code  Volume
# 0     2519.20  2528.20        5610000      Futures     NESIND    5800
# 1     2525.00  2526.15        5610000      Futures     NESIND    2600
# 2     2527.00  2527.00        5610000      Futures     NESIND    2000
# 3     2531.55  2532.20        5609800      Futures     NESIND    2200
# 4     2533.00  2533.00        5609800      Futures     NESIND    2800
# ...       ...      ...            ...          ...        ...     ...
# 7096  2575.55  2577.10          88400      Futures     NESIND     800
# 7097  2577.10  2577.10          88400      Futures     NESIND     400
# 7098  2577.50  2577.50          88400      Futures     NESIND     400
# 7099  2577.50  2577.50          88400      Futures     NESIND       0
# 7100  2576.00  2576.00          88800      Futures     NESIND    1600
#
# [7101 rows x 11 columns]

# %%
df.sort_values('datetime').reset_index(drop=True,inplace=True)

# %%
if product_type == 'options':
    filename = f'data/{symbol}/{symbol}_{product_type}_{strike_price}_{expiry_date}_{interval}_{period}{period_unit}.csv'

elif product_type == 'futures':
    filename = f'data/{symbol}/{symbol}_{product_type}_{expiry_date}_{interval}_{period}{period_unit}.csv'
else:

    raise(ValueError(f'product type is neither "options" or "futures". If trying to get stock data use First Fucntion in 2nd Cell this is for futrues or options data'))
try:

    df.to_csv(filename,index=False)

except OSError as e:
    print(e)
    os.mkdir(f'data/{symbol}')
    df.to_csv(filename,index=False)

# %%
pd.read_csv(filename)
# Out:
#         Close             datetime exchange_code  expiry_date     High  \
# 0     2526.15  2024-05-02 09:15:00           NFO  30-MAY-2024  2550.85
# 1     2527.00  2024-05-02 09:16:00           NFO  30-MAY-2024  2530.15
# 2     2532.20  2024-05-02 09:17:00           NFO  30-MAY-2024  2536.20
# 3     2533.00  2024-05-02 09:18:00           NFO  30-MAY-2024  2533.00
# 4     2536.45  2024-05-02 09:19:00           NFO  30-MAY-2024  2537.10
# ...       ...                  ...           ...          ...      ...
# 7096  2577.10  2024-04-03 15:25:00           NFO  30-MAY-2024  2577.10
# 7097  2577.50  2024-04-03 15:26:00           NFO  30-MAY-2024  2577.50
# 7098  2577.50  2024-04-03 15:27:00           NFO  30-MAY-2024  2577.50
# 7099  2577.50  2024-04-03 15:28:00           NFO  30-MAY-2024  2577.50
# 7100  2576.00  2024-04-03 15:29:00           NFO  30-MAY-2024  2576.00
#
#           Low     Open  open_interest product_type stock_code  Volume
# 0     2519.20  2528.20        5610000      Futures     NESIND    5800
# 1     2525.00  2526.15        5610000      Futures     NESIND    2600
# 2     2527.00  2527.00        5610000      Futures     NESIND    2000
# 3     2531.55  2532.20        5609800      Futures     NESIND    2200
# 4     2533.00  2533.00        5609800      Futures     NESIND    2800
# ...       ...      ...            ...          ...        ...     ...
# 7096  2575.55  2577.10          88400      Futures     NESIND     800
# 7097  2577.10  2577.10          88400      Futures     NESIND     400
# 7098  2577.50  2577.50          88400      Futures     NESIND     400
# 7099  2577.50  2577.50          88400      Futures     NESIND       0
# 7100  2576.00  2576.00          88800      Futures     NESIND    1600
#
# [7101 rows x 11 columns]

# %% [markdown]
# ### To Get Seconds Data of stocks

# %%
symbol = 'NESIND'
date = '2024-05-07'#dt.datetime.today().strftime('%d-%m-%Y')

# %%
data = bz.second_data(symbol,date=date)
data
# Out:
# [**************************                          ]
# 100.0 Completed
#          Close             datetime exchange_code     High      Low     Open  \
# 0      2469.00  2024-05-07 09:07:53           NSE  2469.00  2469.00  2469.00
# 1      2469.90  2024-05-07 09:15:02           NSE  2469.90  2469.90  2469.90
# 2      2460.00  2024-05-07 09:15:13           NSE  2460.00  2460.00  2460.00
# 3      2461.75  2024-05-07 09:15:24           NSE  2461.75  2461.75  2461.75
# 4      2466.20  2024-05-07 09:15:33           NSE  2466.20  2466.20  2466.20
# ...        ...                  ...           ...      ...      ...      ...
# 16088  2508.00  2024-05-07 15:29:55           NSE  2508.00  2508.00  2508.00
# 16089  2508.00  2024-05-07 15:29:56           NSE  2508.00  2508.00  2508.00
# 16090  2508.00  2024-05-07 15:29:57           NSE  2508.00  2508.00  2508.00
# 16091  2508.00  2024-05-07 15:29:58           NSE  2508.00  2508.00  2508.00
# 16092  2506.25  2024-05-07 15:29:59           NSE  2506.25  2506.25  2506.25
#
#       stock_code  Volume
# 0         NESIND       0
# 1         NESIND     523
# 2         NESIND    1297
# 3         NESIND     619
# 4         NESIND    1217
# ...          ...     ...
# 16088     NESIND       0
# 16089     NESIND      42
# 16090     NESIND       2
# 16091     NESIND       0
# 16092     NESIND     101
#
# [16093 rows x 8 columns]

# %%
filename = f'data/{symbol}/{symbol}_1second_{date}.csv'

try:

    data.to_csv(filename,index=False)

except OSError as e:
    print(e)
    os.mkdir(f'data/{symbol}')
    data.to_csv(filename,index=False)

# %%
pd.read_csv(filename)
# Out:
#          Close             datetime exchange_code     High      Low     Open  \
# 0      2469.00  2024-05-07 09:07:53           NSE  2469.00  2469.00  2469.00
# 1      2469.90  2024-05-07 09:15:02           NSE  2469.90  2469.90  2469.90
# 2      2460.00  2024-05-07 09:15:13           NSE  2460.00  2460.00  2460.00
# 3      2461.75  2024-05-07 09:15:24           NSE  2461.75  2461.75  2461.75
# 4      2466.20  2024-05-07 09:15:33           NSE  2466.20  2466.20  2466.20
# ...        ...                  ...           ...      ...      ...      ...
# 16088  2508.00  2024-05-07 15:29:55           NSE  2508.00  2508.00  2508.00
# 16089  2508.00  2024-05-07 15:29:56           NSE  2508.00  2508.00  2508.00
# 16090  2508.00  2024-05-07 15:29:57           NSE  2508.00  2508.00  2508.00
# 16091  2508.00  2024-05-07 15:29:58           NSE  2508.00  2508.00  2508.00
# 16092  2506.25  2024-05-07 15:29:59           NSE  2506.25  2506.25  2506.25
#
#       stock_code  Volume
# 0         NESIND       0
# 1         NESIND     523
# 2         NESIND    1297
# 3         NESIND     619
# 4         NESIND    1217
# ...          ...     ...
# 16088     NESIND       0
# 16089     NESIND      42
# 16090     NESIND       2
# 16091     NESIND       0
# 16092     NESIND     101
#
# [16093 rows x 8 columns]

# %% [markdown]
# ##### To get multiple days of second tick data use below loop
# ### Caution do not use more than 5 days

# %%
dfs = []
for days in range(0,period+1):
    latest_date = dt.date.today()-dt.timedelta(days=days)
    result = bz.download(symbol,interval,'1d',latest_date=latest_date)
    dfs.append(result)
    clear_output()
    print(f'{round(days/period*100,2)} Completed')
# Out:
# 100.0 Completed

# %%
df = pd.concat(dfs,ignore_index=True)
df
# Out:
#         Close             datetime exchange_code     High      Low     Open  \
# 0     2507.40  2024-05-02 09:07:00           NSE  2510.00  2507.40  2510.00
# 1     2512.55  2024-05-02 09:15:00           NSE  2519.00  2507.50  2507.50
# 2     2514.70  2024-05-02 09:16:00           NSE  2515.45  2507.05  2512.50
# 3     2514.50  2024-05-02 09:17:00           NSE  2519.00  2513.25  2514.70
# 4     2517.95  2024-05-02 09:18:00           NSE  2518.80  2514.70  2515.60
# ...       ...                  ...           ...      ...      ...      ...
# 7139  2556.50  2024-04-03 15:25:00           NSE  2558.15  2555.00  2555.35
# 7140  2556.00  2024-04-03 15:26:00           NSE  2557.85  2555.00  2557.75
# 7141  2555.70  2024-04-03 15:27:00           NSE  2557.85  2554.50  2556.00
# 7142  2555.50  2024-04-03 15:28:00           NSE  2556.00  2555.25  2555.65
# 7143  2554.40  2024-04-03 15:29:00           NSE  2555.95  2554.40  2555.25
#
#      stock_code  Volume
# 0        NESIND      37
# 1        NESIND   13646
# 2        NESIND    7678
# 3        NESIND    4407
# 4        NESIND    4112
# ...         ...     ...
# 7139     NESIND   10610
# 7140     NESIND    9914
# 7141     NESIND   13483
# 7142     NESIND    5410
# 7143     NESIND   13575
#
# [7144 rows x 8 columns]

# %%
df.sort_values('datetime').reset_index(drop=True,inplace=True)

# %%
filename = f'data/{symbol}/{symbol}_{interval}_{period}{period_unit}.csv'

try:

    df.to_csv(filename,index=False)

except OSError as e:
    print(e)
    os.mkdir(f'data/{symbol}')
    df.to_csv(filename,index=False)

# %%
pd.read_csv(filename)
# Out:
#         Close             datetime exchange_code     High      Low     Open  \
# 0     2507.40  2024-05-02 09:07:00           NSE  2510.00  2507.40  2510.00
# 1     2512.55  2024-05-02 09:15:00           NSE  2519.00  2507.50  2507.50
# 2     2514.70  2024-05-02 09:16:00           NSE  2515.45  2507.05  2512.50
# 3     2514.50  2024-05-02 09:17:00           NSE  2519.00  2513.25  2514.70
# 4     2517.95  2024-05-02 09:18:00           NSE  2518.80  2514.70  2515.60
# ...       ...                  ...           ...      ...      ...      ...
# 7139  2556.50  2024-04-03 15:25:00           NSE  2558.15  2555.00  2555.35
# 7140  2556.00  2024-04-03 15:26:00           NSE  2557.85  2555.00  2557.75
# 7141  2555.70  2024-04-03 15:27:00           NSE  2557.85  2554.50  2556.00
# 7142  2555.50  2024-04-03 15:28:00           NSE  2556.00  2555.25  2555.65
# 7143  2554.40  2024-04-03 15:29:00           NSE  2555.95  2554.40  2555.25
#
#      stock_code  Volume
# 0        NESIND      37
# 1        NESIND   13646
# 2        NESIND    7678
# 3        NESIND    4407
# 4        NESIND    4112
# ...         ...     ...
# 7139     NESIND   10610
# 7140     NESIND    9914
# 7141     NESIND   13483
# 7142     NESIND    5410
# 7143     NESIND   13575
#
# [7144 rows x 8 columns]
