# %%
import yfinance as yf
import math
import pandas as pd
import numpy as np
import datetime
from IPython.display import clear_output
import time

# %%
class StockFeatures:



    def __init__(self, ticker_symbol):
        self.ticker_symbol = ticker_symbol
        self.data = None

    def average_return(self,interval='1d',period='1y'):
        """
        Calculates the average log return based on the specified frequency.
        """
        data = yf.download(self.ticker_symbol,interval=interval,period=period)
        data['Log_Return'] = np.log(data['Close'] / data['Close'].shift(1))

        self.data = data
        mean = data["Log_Return"].mean()
        return mean*100

    def volatility(self, frequency='daily'):
        sd = self.data.Log_Return.std()
        return sd*100

# %%
stocks_list = pd.read_csv('EQUITY_L.csv')
symbols = list(stocks_list.SYMBOL)

# %%
stocks_list
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      BE
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1965        ZOTA                  Zota Health Care LImited      EQ
# 1966       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1967    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1968   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1969   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0         06-OCT-2008               5            1  INE144J01027            5
# 1         03-MAY-1995              10            1  INE253B01015           10
# 2         19-SEP-2019               1            1  INE466L01038            1
# 3         22-OCT-2021              10            1  INE748C01038           10
# 4         13-AUG-2004              10            1  INE470A01017           10
# ...               ...             ...          ...           ...          ...
# 1965      19-AUG-2019              10            1  INE358U01012           10
# 1966      27-NOV-2012              10            1  INE840M01016           10
# 1967      12-APR-1995              10            1  INE217A01012           10
# 1968      18-APR-2000               1            1  INE010B01027            1
# 1969      13-NOV-2009              10            1  INE768C01010           10
#
# [1970 rows x 8 columns]

# %%
def get_stock_vol(stock_symbol_list,interval,period):
  stock_vol_list = []
  error_list = []

  #ignore this. this is just for time calculating
  start_time = time.time()
  

  for stock in stock_symbol_list:
    stock_fe = StockFeatures(f'{stock}.NS')
    #print(f'Data for {stock} for interval - {interval} and period - {period}')
    i = stock_symbol_list.index(stock)

    time_elapsed = time.time() - start_time
    time_per_item = time_elapsed / (i + 1)
    items_remaining = len(stock_symbol_list) - (i + 1)
    time_remaining = items_remaining * time_per_item
    


    try:
      mean = stock_fe.average_return(interval=interval,period=period)
      sd = stock_fe.volatility()
      length = len(stock_fe.data)
     

      stock_vol_list.append({
          'name':stock,
          'avg_return': round(mean,4),
          'avg_volatility': round(sd,4),
          'len':length,
          'interval':interval,
          'period':period


      })


      print('Succesful :- ',f'{round((symbols.index(stock)+1)/len(symbols)*100,2)}% Completed','\n')
      print(f"Time elapsed: {str(datetime.timedelta(seconds=time_elapsed))} seconds")
      print(f"Time remaining: {str(datetime.timedelta(seconds=time_remaining))} seconds")
      clear_output(wait= True)

    except Exception as e:

      error_list.append({
          'name' : stock,
          'error' : e,
          'interval' : interval,
          'period' : period
      })
      print(f'Error in {stock} :- {round((symbols.index(stock)+1)/len(symbols)*100,2)}% Completed','\n')
      print(f"Time elapsed: {str(datetime.timedelta(seconds=time_elapsed))} seconds")
      print(f"Time remaining: {str(datetime.timedelta(seconds=time_remaining))} seconds")

  print(stock_vol_list)

  data = pd.DataFrame(stock_vol_list)
  error_data = pd.DataFrame(error_list)
  data.to_csv(f'stocks_sd_{interval}_{period}.csv',index=False)
  data.to_csv(f'error_stocks_sd_{interval}_{period}.csv',index=False) if not error_data.empty else print("No Error Found")

  return data,error_data

# %%
data,error = get_stock_vol(symbols,interval='1d',period='1y')

# %%
data_5m,error_5m = get_stock_vol(symbols,interval='1m',period='7d')
# Out:
# [{'name': '20MICRONS', 'avg_return': 0.0, 'avg_volatility': 0.2106, 'len': 1393, 'interval': '1m', 'period': '7d'}, {'name': '21STCENMGM', 'avg_return': 0.2224, 'avg_volatility': 0.6218, 'len': 53, 'interval': '1m', 'period': '7d'}, {'name': '360ONE', 'avg_return': 0.0027, 'avg_volatility': 0.1592, 'len': 2544, 'interval': '1m', 'period': '7d'}, {'name': '3IINFOLTD', 'avg_return': -0.001, 'avg_volatility': 0.1563, 'len': 2408, 'interval': '1m', 'period': '7d'}, {'name': '3MINDIA', 'avg_return': -0.0012, 'avg_volatility': 0.1065, 'len': 1771, 'interval': '1m', 'period': '7d'}, {'name': '3PLAND', 'avg_return': 0.0108, 'avg_volatility': 1.5886, 'len': 396, 'interval': '1m', 'period': '7d'}, {'name': '5PAISA', 'avg_return': 0.0013, 'avg_volatility': 0.1749, 'len': 2333, 'interval': '1m', 'period': '7d'}, {'name': '63MOONS', 'avg_return': -0.005, 'avg_volatility': 0.2117, 'len': 2049, 'interval': '1m', 'period': '7d'}, {'name': 'A2ZINFRA', 'avg_return': -0.0108, 'avg_volatility': 0.9895, 'len': 672, 'interval': '1m', 'period': '7d'}, {'name': 'AAATECH', 'avg_return': 0.0174, 'avg_volatility': 0.9691, 'len': 646, 'interval': '1m', 'period': '7d'}, {'name': 'AAKASH', 'avg_return': 0.004, 'avg_volatility': 0.3783, 'len': 2237, 'interval': '1m', 'period': '7d'}, {'name': 'AAREYDRUGS', 'avg_return': 0.0029, 'avg_volatility': 1.1496, 'len': 501, 'interval': '1m', 'period': '7d'}, {'name': 'AARON', 'avg_return': -0.0018, 'avg_volatility': 0.3071, 'len': 871, 'interval': '1m', 'period': '7d'}, {'name': 'AARTECH', 'avg_return': 0.0146, 'avg_volatility': 0.6063, 'len': 857, 'interval': '1m', 'period': '7d'}, {'name': 'AARTIDRUGS', 'avg_return': 0.0031, 'avg_volatility': 0.1718, 'len': 2454, 'interval': '1m', 'period': '7d'}, {'name': 'AARTIIND', 'avg_return': 0.0037, 'avg_volatility': 0.106, 'len': 2621, 'interval': '1m', 'period': '7d'}, {'name': 'AARTIPHARM', 'avg_return': -0.0011, 'avg_volatility': 0.1307, 'len': 2373, 'interval': '1m', 'period': '7d'}, {'name': 'AARTISURF', 'avg_return': 0.005, 'avg_volatility': 0.2371, 'len': 1545, 'interval': '1m', 'period': '7d'}, {'name': 'AARVEEDEN', 'avg_return': 0.0094, 'avg_volatility': 0.6302, 'len': 674, 'interval': '1m', 'period': '7d'}, {'name': 'AARVI', 'avg_return': 0.0247, 'avg_volatility': 0.4707, 'len': 1040, 'interval': '1m', 'period': '7d'}, {'name': 'AAVAS', 'avg_return': 0.0039, 'avg_volatility': 0.1928, 'len': 2619, 'interval': '1m', 'period': '7d'}, {'name': 'ABAN', 'avg_return': 0.0074, 'avg_volatility': 0.4181, 'len': 1296, 'interval': '1m', 'period': '7d'}, {'name': 'ABB', 'avg_return': 0.0017, 'avg_volatility': 0.0825, 'len': 2621, 'interval': '1m', 'period': '7d'}, {'name': 'ABBOTINDIA', 'avg_return': -0.0012, 'avg_volatility': 0.0745, 'len': 2377, 'interval': '1m', 'period': '7d'}, {'name': 'ABCAPITAL', 'avg_return': 0.0003, 'avg_volatility': 0.1085, 'len': 2620, 'interval': '1m', 'period': '7d'}, {'name': 'ABFRL', 'avg_return': -0.0004, 'avg_volatility': 0.111, 'len': 2619, 'interval': '1m', 'period': '7d'}, {'name': 'ABMINTLLTD', 'avg_return': 0.0138, 'avg_volatility': 1.974, 'len': 135, 'interval': '1m', 'period': '7d'}, {'name': 'ABSLAMC', 'avg_return': 0.002, 'avg_volatility': 0.1085, 'len': 2582, 'interval': '1m', 'period': '7d'}, {'name': 'ACC', 'avg_return': -0.0024, 'avg_volatility': 0.0788, 'len': 2619, 'interval': '1m', 'period': '7d'}, {'name': 'ACCELYA', 'avg_return': 0.0017, 'avg_volatility': 0.1605, 'len': 1889, 'interval': '1m', 'period': '7d'}, {'name': 'ACCURACY', 'avg_return': -0.1618, 'avg_volatility': 0.5116, 'len': 42, 'interval': '1m', 'period': '7d'}, {'name': 'ACE', 'avg_return': -0.0024, 'avg_volatility': 0.1574, 'len': 2620, 'interval': '1m', 'period': '7d'}, {'name': 'ACEINTEG', 'avg_return': 0.0061, 'avg_volatility': 1.1387, 'len': 343, 'interval': '1m', 'period': '7d'}, {'name': 'ACI', 'avg_return': 0.0018, 'avg_volatility': 0.1457, 'len': 2618, 'interval': '1m', 'period': '7d'}, {'name': 'ACL', 'avg_return': 0.0002, 'avg_volatility': 0.2686, 'le ...
# No Error Found

# %%
sd_1d = pd.read_csv('stocks_sd_1d_1y.csv')
sd_1m = pd.read_csv('stocks_sd_1m_7d.csv')

# %%
sd_1d = sd_1d[sd_1d.len > 200].sort_values('avg_volatility',ascending=False).reset_index()
sd_1m = sd_1m[sd_1m.len > 2000].sort_values('avg_volatility',ascending=False).reset_index()

# %%
sd_1m = sd_1m[['name','avg_return','avg_volatility','len','interval','period',' SERIES_x']]

# %%
sd_1m = sd_1m[sd_1m[' SERIES_x']=='EQ']
sd_1m
# Out:
#            name  avg_return  avg_volatility   len interval period  SERIES_x
# 2       SHRENIK      0.0000          3.0202  2321       1m     7d        EQ
# 5     KBCGLOBAL      0.0047          1.4236  2261       1m     7d        EQ
# 7      GTLINFRA      0.0000          1.3160  2615       1m     7d        EQ
# 8      SUNDARAM      0.0054          1.0271  2280       1m     7d        EQ
# 9          SHAH      0.0031          0.8380  2231       1m     7d        EQ
# ..          ...         ...             ...   ...      ...    ...       ...
# 991         ITC      0.0006          0.0544  2621       1m     7d        EQ
# 992   ICICIBANK      0.0009          0.0542  2622       1m     7d        EQ
# 993       ROUTE     -0.0002          0.0539  2488       1m     7d        EQ
# 994    RELIANCE     -0.0003          0.0538  2622       1m     7d        EQ
# 995  HINDUNILVR     -0.0008          0.0391  2622       1m     7d        EQ
#
# [961 rows x 7 columns]

# %%
sd_1d = pd.merge(sd_1d,stocks_list,left_on='name',right_on='SYMBOL',how='inner')

# %%
sd_1d = sd_1d[['name','avg_return','avg_volatility','len','interval','period',' SERIES']]
sd_1d = sd_1d[sd_1d[' SERIES'] == 'EQ']
# Out:
#             name  avg_return  avg_volatility  len interval period  SERIES
# 6       MANORAMA     -0.3304         10.3458  245       1d     1y      EQ
# 7        NIITLTD     -0.4993          9.6912  246       1d     1y      EQ
# 8           CGCL     -0.4182          9.3350  246       1d     1y      EQ
# 16           ACL     -0.0400          4.6121  246       1d     1y      EQ
# 18       FCSSOFT      0.2688          4.4654  246       1d     1y      EQ
# ...          ...         ...             ...  ...      ...    ...     ...
# 1841   BRITANNIA      0.0444          1.0891  245       1d     1y      EQ
# 1842   BATAINDIA     -0.0038          1.0842  246       1d     1y      EQ
# 1843  ASIANPAINT      0.0064          1.0479  246       1d     1y      EQ
# 1844  HINDUNILVR     -0.0521          1.0080  246       1d     1y      EQ
# 1845   ICICIBANK      0.0840          0.9702  246       1d     1y      EQ
#
# [1533 rows x 7 columns]

# %%
sd_1d.reset_index()['index'].drop(columns= ('index'),inplace=True)

# %%
sd_1d.reset_index()
# Out:
#       index        name  avg_return  avg_volatility  len interval period  \
# 0         6    MANORAMA     -0.3304         10.3458  245       1d     1y
# 1         7     NIITLTD     -0.4993          9.6912  246       1d     1y
# 2         8        CGCL     -0.4182          9.3350  246       1d     1y
# 3        16         ACL     -0.0400          4.6121  246       1d     1y
# 4        18     FCSSOFT      0.2688          4.4654  246       1d     1y
# ...     ...         ...         ...             ...  ...      ...    ...
# 1528   1841   BRITANNIA      0.0444          1.0891  245       1d     1y
# 1529   1842   BATAINDIA     -0.0038          1.0842  246       1d     1y
# 1530   1843  ASIANPAINT      0.0064          1.0479  246       1d     1y
# 1531   1844  HINDUNILVR     -0.0521          1.0080  246       1d     1y
# 1532   1845   ICICIBANK      0.0840          0.9702  246       1d     1y
#
#       SERIES
# 0         EQ
# 1         EQ
# 2         EQ
# 3         EQ
# 4         EQ
# ...      ...
# 1528      EQ
# 1529      EQ
# 1530      EQ
# 1531      EQ
# 1532      EQ
#
# [1533 rows x 8 columns]
